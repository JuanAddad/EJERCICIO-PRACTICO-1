# %%
# Imprimiendo un mensaje
print("¡Hola, Jupyter Notebook está funcionando correctamente!")

# Realizar una operación matemática básica
resultado = 2 + 3
print(f"El resultado de 2 + 3 es: {resultado}")

# Crear una lista y mostrarla
mi_lista = [1, 2, 3, 4, 5]
print("Esta es mi lista:", mi_lista)

import pandas as pd  # Para cargar y trabajar con datos
import matplotlib.pyplot as plt  # Para gráficos
# Out:
# ¡Hola, Jupyter Notebook está funcionando correctamente!
# El resultado de 2 + 3 es: 5
# Esta es mi lista: [1, 2, 3, 4, 5]

# %%
# Carga del archivo CSV con codificación especificada
df = pd.read_csv("wfs_behaviors_and_records_508p-546d-98r_20220722173739.csv", encoding="latin1")



# Información general del dataset
df.info()

# Mostrar las primeras filas
df.head()
# Out:
# C:\Users\Bautista\AppData\Local\Temp\ipykernel_14120\3627499063.py:2: DtypeWarning: Columns (35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("wfs_behaviors_and_records_508p-546d-98r_20220722173739.csv", encoding="latin1")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411948 entries, 0 to 411947
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   sub_ID                   411948 non-null  int64
#  1   sub_fname                411948 non-null  object
#  2   sub_lname                411948 non-null  object
#  3   sub_age                  411948 non-null  int64
#  4   sub_sex                  411948 non-null  object
#  5   sub_shift                411948 non-null  object
#  6   sub_team                 411948 non-null  object
#  7   sub_role                 411948 non-null  object
# ...
