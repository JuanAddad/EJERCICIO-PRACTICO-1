# %%
# Imprimiendo un mensaje
print("¡Hola, Jupyter Notebook está funcionando correctamente!")

# Realizar una operación matemática básica
resultado = 2 + 3
print(f"El resultado de 2 + 3 es: {resultado}")

# Crear una lista y mostrarla
mi_lista = [1, 2, 3, 4, 5]
print("Esta es mi lista:", mi_lista)

import pandas as pd  # Para cargar y trabajar con datos
import matplotlib.pyplot as plt  # Para gráficos
# Out:
# ¡Hola, Jupyter Notebook está funcionando correctamente!
# El resultado de 2 + 3 es: 5
# Esta es mi lista: [1, 2, 3, 4, 5]

# %%
# Carga del archivo CSV con codificación especificada
df = pd.read_csv("dataset1_ambiente-financiero-trimestral_2023_2.csv", encoding="latin1")

# Información general del dataset
df.info()

# Mostrar las primeras filas
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6857 entries, 0 to 6856
# Data columns (total 33 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   impacto_presupuestario_anio            6857 non-null   int64
#  1   impacto_presupuestario_mes             6857 non-null   int64
#  2   jurisdiccion_id                        6857 non-null   int64
#  3   jurisdiccion_desc                      6857 non-null   object
#  4   servicio_id                            6857 non-null   int64
#  5    servicio_desc                         6857 non-null   object
#  6   programa_id                            6857 non-null   int64
#  7   programa_desc                          6857 non-null   object
#  8   subprograma_id                         6857 non-null   int64
#  9   subprograma_desc                       6857 non-null   object
#  10  proyecto_id                            6857 non-null   int64
#  11  proyecto_desc                          6857 non-null   object
#  12  actividad_id                           6857 non-null   int64
#  13  actividad_desc                         6857 non-null   object
#  14  obra_id                                6857 non-null   int64
#  15  obra_desc                              6857 non-null   object
#  16  fuente_financiamiento_id               6857 non-null   float64
#  17  fuente_financiamiento_desc             6857 non-null   object
#  18   finalidad_funcion_id                  6857 non-null   float64
#  19   finalidad_funcion_desc                6857 non-null   object
#  20  clasificador_economico_8_digitos_id    6857 non-null   int64
#  21  clasificador_economico_8_digitos_desc  6857 non-null   object
#  22  inciso_id                              6857 non-null   int64
#  23  inciso_desc                            6857 non-null   object
#  24  principal_id                           6857 non-null   int64
#  25  principal_desc                         6857 non-null   object
#  26  parcial_id                             6857 non-null   int64
#  27  parcial_desc                           6857 non-null   object
#  28  subparcial_id                          6857 non-null   int64
#  29  subparcial_desc                        6857 non-null   object
#  30  credito_presupuestado                  6857 non-null   object
#  31  credito_vigente                        6857 non-null   object
#  32  credito_devengado                      6857 non-null   object
# dtypes: float64(2), int64(14), object(17)
# memory usage: 1.7+ MB
#    impacto_presupuestario_anio  impacto_presupuestario_mes  jurisdiccion_id  \
# 0                         2023                           6               30
# 1                         2023                           6               30
# 2                         2023                           6               41
# 3                         2023                           6               41
# 4                         2023                           6               41
#
#          jurisdiccion_desc  servicio_id                      servicio_desc  \
# 0  Ministerio del Interior          201  Dirección Nacional de Migraciones
# 1  Ministerio del Interior          201  Dirección Nacional de Migraciones
# 2  Ministerio de Seguridad          343            Ministerio de Seguridad
# 3  Ministerio de Seguridad          380         Prefectura Naval Argentina
# 4  Ministerio de Seguridad          380         Prefectura Naval Argentina
#
#    programa_id                                      programa_desc  \
# 0           16  Control de Ingresos y Egresos, Admisión y Perm...
# 1           16  Control de Ingresos y Egresos, Admisión y Perm...
# 2           50               Articulación Federal de la Seguridad
# 3           40                  Operaciones de Seguridad Interior
# 4           40                  Operaciones de Seguridad Interior
#
#    subprograma_id                      subprograma_desc  ...  \
# 0               1                          Obras Varias  ...
# 1               1                          Obras Varias  ...
# 2               0  Articulación Federal de la Seguridad  ...
# 3               0     Operaciones de Seguridad Interior  ...
# 4               0     Operaciones de Seguridad Interior  ...
#
#                inciso_desc principal_id                      principal_desc  \
# 0            Bienes de uso            2                      Construcciones
# 1            Bienes de uso            2                      Construcciones
# 2  Servicios no personales            4  Servicios técnicos y profesionales
# 3       Gastos en personal            1                 Personal permanente
# 4       Gastos en personal            1                 Personal permanente
#
#   parcial_id                                       parcial_desc subparcial_id  \
# 0          1        Construcciones en bienes de dominio privado             0
# 1          1        Construcciones en bienes de dominio privado             0
# 2          1  Estudios, investigaciones y proyectos de facti...             0
# 3          7                                       Complementos             0
# 4          3                Retribuciones que no hacen al cargo             0
#
#                                      subparcial_desc credito_presupuestado  \
# 0        Construcciones en bienes de dominio privado             121800000
# 1        Construcciones en bienes de dominio privado              60000000
# 2  Estudios, investigaciones y proyectos de facti...                     0
# 3                                       Complementos             676753467
# 4                Retribuciones que no hacen al cargo            1381485483
#
#    credito_vigente credito_devengado
# 0        121800000                 0
# 1         60000000                 0
# 2           100000                 0
# 3        676753467        6221249,45
# 4       1381485483       68910754,55
#
# [5 rows x 33 columns]
